# %% [markdown]
# # IMPORT

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import matplotlib as mpl
import os
from sklearn.svm import SVR
from sklearn import metrics
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split ,GridSearchCV , RandomizedSearchCV

# %%
#matplotlib.rcParams('font.family') = 'tahoma'

# %%
url = "https://covid19.ddc.moph.go.th/api/Cases/timeline-cases-by-provinces"
r = requests.get(url)
j = r.json()
cov = pd.DataFrame(j)

# %%
dfs = cov.pivot_table(columns="txn_date",index="province", values = "new_case_excludeabroad")

# %%
dfs = dfs.sort_values(by="2022-02-26")
dfs
# Out:
# txn_date       2021-04-01  2021-04-02  2021-04-03  2021-04-04  2021-04-05  \
# province
# ไม่ระบุ                 0           0           0           0           0
# ลำปาง                   0           0           0           0           0
# ลำพูน                   0           0           0           0           0
# แม่ฮ่องสอน              0           0           0           0           0
# บึงกาฬ                  0           0           0           0           0
# ...                   ...         ...         ...         ...         ...
# นครราชสีมา              0           0           0           0           0
# สมุทรปราการ             3           5           4           9           9
# นนทบุรี                 0           3           4           2           4
# ชลบุรี                  0           0           1           7           7
# กรุงเทพมหานคร           7          20          32          35          46
#
# txn_date       2021-04-06  2021-04-07  2021-04-08  2021-04-09  2021-04-10  \
# province
# ไม่ระบุ                 0           0           0           0           0
# ลำปาง                   0           1           1           1           6
# ลำพูน                   0           0           0           0           2
# แม่ฮ่องสอน              0           0           0           0           0
# บึงกาฬ                  0           0           0           0           0
# ...                   ...         ...         ...         ...         ...
# นครราชสีมา              0           0           0           6          10
# สมุทรปราการ            20          30          23          50          75
# นนทบุรี                 1           8          18           6           1
# ชลบุรี                 18          11          14          46         101
# กรุงเทพมหานคร         156         216          95         266         185
#
# txn_date       ...  2022-02-17  2022-02-18  2022-02-19  2022-02-20  \
# province       ...
# ไม่ระบุ        ...           0           0           0           0
# ลำปาง          ...          49          41          72          33
# ลำพูน          ...          11          18          11          12
# แม่ฮ่องสอน     ...          10          12           9          11
# บึงกาฬ         ...          35          85          28          89
# ...            ...         ...         ...         ...         ...
# นครราชสีมา     ...         456         486         580         414
# สมุทรปราการ    ...         872         958         974         976
# นนทบุรี        ...         423         596         770         762
# ชลบุรี         ...         821         811         973         828
# กรุงเทพมหานคร  ...        3069        3500        3205        2744
#
# txn_date       2022-02-21  2022-02-22  2022-02-23  2022-02-24  2022-02-25  \
# province
# ไม่ระบุ                 0           0           0           0           0
# ลำปาง                 111          30          69         105          80
# ลำพูน                  10          19          24           9           8
# แม่ฮ่องสอน             12          10          16          10          13
# บึงกาฬ                 73          47          26          51          87
# ...                   ...         ...         ...         ...         ...
# นครราชสีมา            573         717         589         629         661
# สมุทรปราการ           926         887         990        1005        1129
# นนทบุรี               852         792         724         875         775
# ชลบุรี                884         929        1369        1250        1419
# กรุงเทพมหานคร        2755        2649        3163        3260        3338
#
# txn_date       2022-02-26
# province
# ไม่ระบุ                 0
# ลำปาง                   0
# ลำพูน                   9
# แม่ฮ่องสอน             15
# บึงกาฬ                 58
# ...                   ...
# นครราชสีมา            873
# สมุทรปราการ          1120
# นนทบุรี              1129
# ชลบุรี               1310
# กรุงเทพมหานคร        3265
#
# [78 rows x 332 columns]

# %%
dfa = dfs.iloc[: , -31:]

# %% [raw]
# # plt.figure(figsize=(50,50))
# sns.set_style("darkgrid")
# plt.rcParams["font.family"] = "tahoma"
# sns.color_palette("rocket_r", as_cmap=True)
# ax = sns.heatmap(dfa ,annot=True ,linewidths=.1 ,fmt="d" ,square=True ,cmap="YlOrBr" )
# plt.savefig('saving-a-seaborn-plot-as-png-file-transparent.png',
#            transparent=True)

# %% [markdown]
# # Line plot

# %%
url2 = "https://covid19.ddc.moph.go.th/api/Cases/timeline-cases-all"
d = requests.get(url2)
js = d.json()

ds_raw = pd.DataFrame(js)
ds2 = ds_raw[["txn_date","new_case"]]

# %%
ds2 = ds2

# %%
ds2 = ds2.reset_index(drop=True)
ds2.shape
# Out:
# (332, 2)

# %%
plt.figure(figsize=(16,9))
palette = sns.color_palette("mako_r")
sns.scatterplot(data=ds2 ,x="txn_date" ,y="new_case" ,markers=True,palette=palette)
# Out:
# <AxesSubplot:xlabel='txn_date', ylabel='new_case'>

# %%
xdf = np.arange(len(ds2))

# %%
ydf = ds2["new_case"]
xdf = xdf.reshape(-1,1)

# %%
SVR_model = SVR(kernel="poly" ,degree=3)

# %%
SVR_model
# Out:
# SVR(kernel='poly')

# %%
svr = SVR_model.fit(xdf,ydf)
