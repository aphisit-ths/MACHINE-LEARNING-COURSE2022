# %% [markdown]
# ###  <font color='Blue'>Import importance library </font>

# %% [markdown]
# > # DATA EXPLORATION

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %% [markdown]
# ##### Read CSV. FILE

# %% [markdown]
# > #### ได้ทำการเพิ่ม Non ASCII เข้าไปใน Data

# %%
data = pd.read_csv("./Resoures/sample_data.csv")
data
# Out:
#          X     Y        Z
# 0       13  1927  catÙ‹Ð©
# 1      NaN  2300      dog
# 2       15   NaN     bird
# 3       16  5959      cat
# 4   16Ù‹Ð©    AB      cat
# 5      NaN  4594      dog
# 6       19  1927      cat
# 7       20  2879  birdหมา
# 8   21Ù‹Ð©   NaN      NaN
# 9        0  4096      cat
# 10       A  6730      cat
# 11      25     0     bird
# 12       0  2792      dog
# 13      33  2575    dogนก
# 14    1000  4959     bird
# 15      35  1927      cat
# 16      36  4580      dog
# 17      40  5869      NaN
# 18     NaN  4178      dog
# 19      45   NaN      cat

# %% [markdown]
# > ### ข้อมูลที่อ่านมานั้นยังมีความผิดพลาดหลายประการ ที่เห็นได้ชัดก็คือ NaN ,Invalid ที่เกิดขึ้น

# %%
data.info(verbose="true")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       17 non-null     object
#  1   Y       17 non-null     object
#  2   Z       18 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %% [markdown]
# ---

# %% [markdown]
# > # DATA CLEANING

# %% [markdown]
# ---

# %% [markdown]
# ### Correct Errors (delete non ASCII)

# %% [markdown]
# > #### Replace every samples that ASCII with empty string

# %%
data.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
data
# Out:
#        X     Y     Z
# 0     13  1927   cat
# 1    NaN  2300   dog
# 2     15   NaN  bird
# 3     16  5959   cat
# 4     16    AB   cat
# 5    NaN  4594   dog
# 6     19  1927   cat
# 7     20  2879  bird
# 8     21   NaN   NaN
# 9      0  4096   cat
# 10     A  6730   cat
# 11    25     0  bird
# 12     0  2792   dog
# 13    33  2575   dog
# 14  1000  4959  bird
# 15    35  1927   cat
# 16    36  4580   dog
# 17    40  5869   NaN
# 18   NaN  4178   dog
# 19    45   NaN   cat

# %% [markdown]
# > ##### พบว่าตัวอักษรภาษาไทย หรืออักขระพิเศษนั้นถูกแทนที่ด้วย Empty String

# %% [markdown]
# ## Convert data type from object to suitable types

# %% [markdown]
# > #### แทนค่า samples ที่ไม่ได้เป็น numberic ให้เป็น NaN

# %%
data['X'] = pd.to_numeric(data['X'],errors='coerce' , downcast="signed")
data['Y'] = pd.to_numeric(data['Y'],errors='coerce'  )
#แทนค่า samples ที่ไม่ได้เป็น numberic ให้เป็น NaN
data
# Out:
#          X       Y     Z
# 0     13.0  1927.0   cat
# 1      NaN  2300.0   dog
# 2     15.0     NaN  bird
# 3     16.0  5959.0   cat
# 4     16.0     NaN   cat
# 5      NaN  4594.0   dog
# 6     19.0  1927.0   cat
# 7     20.0  2879.0  bird
# 8     21.0     NaN   NaN
# 9      0.0  4096.0   cat
# 10     NaN  6730.0   cat
# 11    25.0     0.0  bird
# 12     0.0  2792.0   dog
# 13    33.0  2575.0   dog
# 14  1000.0  4959.0  bird
# 15    35.0  1927.0   cat
# 16    36.0  4580.0   dog
# 17    40.0  5869.0   NaN
# 18     NaN  4178.0   dog
# 19    45.0     NaN   cat

# %%
data.info(verbose="true")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       16 non-null     float64
#  1   Y       16 non-null     float64
#  2   Z       18 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 608.0+ bytes

# %%
data.describe()
# Out:
#                  X            Y
# count    16.000000    16.000000
# mean     83.375000  3580.750000
# std     244.778233  1828.473808
# min       0.000000     0.000000
# 25%      15.750000  2206.750000
# 50%      20.500000  3487.500000
# 75%      35.250000  4685.250000
# max    1000.000000  6730.000000

# %% [markdown]
# ## Drop rows with NA > 1

# %%
data
# Out:
#          X       Y     Z
# 0     13.0  1927.0   cat
# 1      NaN  2300.0   dog
# 2     15.0     NaN  bird
# 3     16.0  5959.0   cat
# 4     16.0     NaN   cat
# 5      NaN  4594.0   dog
# 6     19.0  1927.0   cat
# 7     20.0  2879.0  bird
# 8     21.0     NaN   NaN
# 9      0.0  4096.0   cat
# 10     NaN  6730.0   cat
# 11    25.0     0.0  bird
# 12     0.0  2792.0   dog
# 13    33.0  2575.0   dog
# 14  1000.0  4959.0  bird
# 15    35.0  1927.0   cat
# 16    36.0  4580.0   dog
# 17    40.0  5869.0   NaN
# 18     NaN  4178.0   dog
# 19    45.0     NaN   cat

# %%
data.dropna(thresh=2).reset_index(drop=True)
# Out:
#          X       Y     Z
# 0     13.0  1927.0   cat
# 1      NaN  2300.0   dog
# 2     15.0     NaN  bird
# 3     16.0  5959.0   cat
# 4     16.0     NaN   cat
# 5      NaN  4594.0   dog
# 6     19.0  1927.0   cat
# 7     20.0  2879.0  bird
# 8      0.0  4096.0   cat
# 9      NaN  6730.0   cat
# 10    25.0     0.0  bird
# 11     0.0  2792.0   dog
# 12    33.0  2575.0   dog
# 13  1000.0  4959.0  bird
# 14    35.0  1927.0   cat
# 15    36.0  4580.0   dog
# 16    40.0  5869.0   NaN
# 17     NaN  4178.0   dog
# 18    45.0     NaN   cat

# %% [markdown]
# ## Replace NAN ( X,Y with mean value , Z with  previous rows )

# %%
data.describe()
# Out:
#                  X            Y
# count    16.000000    16.000000
# mean     83.375000  3580.750000
# std     244.778233  1828.473808
# min       0.000000     0.000000
# 25%      15.750000  2206.750000
# 50%      20.500000  3487.500000
# 75%      35.250000  4685.250000
# max    1000.000000  6730.000000

# %%
data.fillna(data.mean(),inplace=True)
currect_data = data.fillna(method="ffill")
currect_data
# Out:
#            X        Y     Z
# 0     13.000  1927.00   cat
# 1     83.375  2300.00   dog
# 2     15.000  3580.75  bird
# 3     16.000  5959.00   cat
# 4     16.000  3580.75   cat
# 5     83.375  4594.00   dog
# 6     19.000  1927.00   cat
# 7     20.000  2879.00  bird
# 8     21.000  3580.75  bird
# 9      0.000  4096.00   cat
# 10    83.375  6730.00   cat
# 11    25.000     0.00  bird
# 12     0.000  2792.00   dog
# 13    33.000  2575.00   dog
# 14  1000.000  4959.00  bird
# 15    35.000  1927.00   cat
# 16    36.000  4580.00   dog
# 17    40.000  5869.00   dog
# 18    83.375  4178.00   dog
# 19    45.000  3580.75   cat

# %% [markdown]
# ----

# %% [markdown]
# # Tranfrom Data

# %% [markdown]
# ----

# %%
minmax_scaler = MinMaxScaler()
std_scaler = StandardScaler()

# %%
x_scaled = minmax_scaler.fit_transform(currect_data[['X']])
y_scaled = std_scaler.fit_transform(currect_data[['Y']])

currect_data
# Out:
#            X         Y     Z
# 0   0.013000 -1.044361   cat
# 1   0.083375 -0.808807   dog
# 2   0.015000  0.000000  bird
# 3   0.016000  1.501890   cat
# 4   0.016000  0.000000   cat
# 5   0.083375  0.639878   dog
# 6   0.019000 -1.044361   cat
# 7   0.020000 -0.443163  bird
# 8   0.021000  0.000000  bird
# 9   0.000000  0.325386   cat
# 10  0.083375  1.988785   cat
# 11  0.025000 -2.261281  bird
# 12  0.000000 -0.498104   dog
# 13  0.033000 -0.635142   dog
# 14  1.000000  0.870379  bird
# 15  0.035000 -1.044361   cat
# 16  0.036000  0.631037   dog
# 17  0.040000  1.445054   dog
# 18  0.083375  0.377170   dog
# 19  0.045000  0.000000   cat

# %% [markdown]
# > #### Blockplot

# %%
def _boxplot(data,col):
    sns.set_theme(style="whitegrid")
    sns.boxplot(y=data[col])

# %%
_boxplot(currect_data,"X")

# %%
_boxplot(currect_data,"Y")

# %% [markdown]
# ## Remove outliers

# %%
def outliers (scaled_ft, cols):
    Q1 = scaled_ft[cols].quantile(0.25)
    Q3 = scaled_ft[cols].quantile(0.75)
    
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    ls = scaled_ft.index[(scaled_ft[cols] < lower) | (scaled_ft[cols]  > upper) ]
    return ls

# %%
idx_lst = []
for cols in ["X","Y"]:
    idx_lst.extend(outliers(currect_data,cols))

# %%
def remove(scaled_df,ls):
    ls = sorted(set(ls))
    scaled_df = scaled_df.drop(ls).reset_index()
    return scaled_df

# %%
cleaned_data = remove(currect_data,idx_lst)
cleaned_data
# Out:
#     index         X         Y     Z
# 0       0  0.013000 -1.044361   cat
# 1       1  0.083375 -0.808807   dog
# 2       2  0.015000  0.000000  bird
# 3       3  0.016000  1.501890   cat
# 4       4  0.016000  0.000000   cat
# 5       5  0.083375  0.639878   dog
# 6       6  0.019000 -1.044361   cat
# 7       7  0.020000 -0.443163  bird
# 8       8  0.021000  0.000000  bird
# 9       9  0.000000  0.325386   cat
# 10     10  0.083375  1.988785   cat
# 11     11  0.025000 -2.261281  bird
# 12     12  0.000000 -0.498104   dog
# 13     13  0.033000 -0.635142   dog
# 14     15  0.035000 -1.044361   cat
# 15     16  0.036000  0.631037   dog
# 16     17  0.040000  1.445054   dog
# 17     18  0.083375  0.377170   dog
# 18     19  0.045000  0.000000   cat

# %%
_boxplot(cleaned_data,"X")

# %%
_boxplot(currect_data,"X")

# %%
_boxplot(cleaned_data,"Y")

# %%
_boxplot(currect_data,"Y")

# %%
sns.scatterplot(x=cleaned_data['index'] , y=currect_data["X"])
# Out:
# <AxesSubplot:xlabel='index', ylabel='X'>

# %%
sns.scatterplot(x=cleaned_data['index'] , y=cleaned_data["X"])
# Out:
# <AxesSubplot:xlabel='index', ylabel='X'>
