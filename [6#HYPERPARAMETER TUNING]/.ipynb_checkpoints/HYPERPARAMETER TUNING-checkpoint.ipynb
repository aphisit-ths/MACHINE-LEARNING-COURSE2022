# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import preprocessing
from sklearn import metrics
import pandas_datareader.data as web
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# > ## 5.1 (a) Get Data

# %%
stk_tickers = ['MSFT', 'IBM', 'GOOGL']
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['SP500', 'DJIA', 'VIXCLS']

# %%
stk_data = web.DataReader(stk_tickers, 'yahoo')
ccy_data = web.DataReader(ccy_tickers, 'fred')
idx_data = web.DataReader(idx_tickers, 'fred')

# %%
stk_data
# Out:
# Attributes   Adj Close                                Close              \
# Symbols           MSFT         IBM         GOOG        MSFT         IBM
# Date
# 2017-02-17   60.446503  136.764084   828.070007   64.620003  172.724670
# 2017-02-21   60.324913  136.453751   831.659973   64.489998  172.332703
# 2017-02-22   60.203300  137.127441   830.760010   64.360001  173.183563
# 2017-02-23   60.446503  137.505951   831.330017   64.620003  173.661575
# 2017-02-24   60.446503  137.278809   828.640015   64.620003  173.374756
# ...                ...         ...          ...         ...         ...
# 2022-02-10  302.380005  133.520004  2772.050049  302.380005  133.520004
# 2022-02-11  295.040009  132.690002  2682.600098  295.040009  132.690002
# 2022-02-14  295.000000  130.149994  2706.000000  295.000000  130.149994
# 2022-02-15  300.470001  129.940002  2728.510010  300.470001  129.940002
# 2022-02-16  299.500000  129.179993  2749.750000  299.500000  129.179993
#
# Attributes                     High                                  Low  \
# Symbols            GOOG        MSFT         IBM         GOOG        MSFT
# Date
# 2017-02-17   828.070007   64.690002  173.585083   828.070007   64.300003
# 2017-02-21   831.659973   64.949997  172.839386   833.450012   64.449997
# 2017-02-22   830.760010   64.389999  173.365204   833.250000   64.050003
# 2017-02-23   831.330017   64.730003  174.474182   832.460022   64.190002
# 2017-02-24   828.640015   64.800003  173.508606   829.000000   64.139999
# ...                 ...         ...         ...          ...         ...
# 2022-02-10  2772.050049  309.119995  136.559998  2828.620117  300.700012
# 2022-02-11  2682.600098  304.290009  134.710007  2785.665039  294.220001
# 2022-02-14  2706.000000  296.760010  132.649994  2723.330078  291.350006
# 2022-02-15  2728.510010  300.799988  131.679993  2758.000000  297.019989
# 2022-02-16  2749.750000  300.869995  130.440002  2758.919922  293.679993
#
# Attributes                                 Open                           \
# Symbols            IBM         GOOG        MSFT         IBM         GOOG
# Date
# 2017-02-17  172.084137   821.655029   64.470001  173.279160   823.020020
# 2017-02-21  171.242828   828.349976   64.610001  172.657745   828.659973
# 2017-02-22  172.170166   828.640015   64.330002  172.170166   828.659973
# 2017-02-23  172.963669   822.880005   64.419998  173.996170   830.119995
# 2017-02-24  171.978973   824.200012   64.529999  172.284897   827.729980
# ...                ...          ...         ...         ...          ...
# 2022-02-10  133.169998  2761.000000  304.040009  135.470001  2790.000000
# 2022-02-11  132.380005  2665.770020  303.190002  133.899994  2775.000000
# 2022-02-14  129.070007  2666.040039  293.769989  132.589996  2667.310059
# 2022-02-15  129.610001  2710.790039  300.010010  130.639999  2749.429932
# 2022-02-16  128.259995  2696.472900  298.369995  129.449997  2728.610107
#
# Attributes      Volume
# Symbols           MSFT        IBM       GOOG
# Date
# 2017-02-17  21248800.0  3715915.0  1611000.0
# 2017-02-21  20655900.0  4686394.0  1262300.0
# 2017-02-22  19292700.0  3159443.0   982900.0
# 2017-02-23  20273100.0  2387495.0  1472800.0
# 2017-02-24  21796800.0  3451905.0  1392200.0
# ...                ...        ...        ...
# 2022-02-10  45386200.0  5978600.0  1650900.0
# 2022-02-11  39143900.0  4175600.0  1937700.0
# 2022-02-14  36339400.0  5344300.0  1338700.0
# 2022-02-15  27379500.0  4395700.0  1328900.0
# 2022-02-16  29956000.0  4874500.0  1278500.0
#
# [1259 rows x 18 columns]

# %%
stk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-02-17 to 2022-02-16
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, MSFT)   1259 non-null   float64
#  1   (Adj Close, IBM)    1259 non-null   float64
#  2   (Adj Close, GOOGL)  1259 non-null   float64
#  3   (Close, MSFT)       1259 non-null   float64
#  4   (Close, IBM)        1259 non-null   float64
#  5   (Close, GOOGL)      1259 non-null   float64
#  6   (High, MSFT)        1259 non-null   float64
#  7   (High, IBM)         1259 non-null   float64
#  8   (High, GOOGL)       1259 non-null   float64
#  9   (Low, MSFT)         1259 non-null   float64
#  10  (Low, IBM)          1259 non-null   float64
#  11  (Low, GOOGL)        1259 non-null   float64
#  12  (Open, MSFT)        1259 non-null   float64
#  13  (Open, IBM)         1259 non-null   float64
#  14  (Open, GOOGL)       1259 non-null   float64
#  15  (Volume, MSFT)      1259 non-null   float64
#  16  (Volume, IBM)       1259 non-null   float64
#  17  (Volume, GOOGL)     1259 non-null   float64
# dtypes: float64(18)
# memory usage: 186.9 KB

# %%
ccy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1300 entries, 2017-02-20 to 2022-02-11
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEXJPUS  1243 non-null   float64
#  1   DEXUSUK  1243 non-null   float64
# dtypes: float64(2)
# memory usage: 30.5 KB

# %%
idx_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1303 entries, 2017-02-20 to 2022-02-16
# Freq: B
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SP500   1258 non-null   float64
#  1   DJIA    1258 non-null   float64
#  2   VIXCLS  1257 non-null   float64
# dtypes: float64(3)
# memory usage: 40.7 KB

# %%
stk_data.head()
# Out:
# Attributes  Adj Close                              Close              \
# Symbols          MSFT         IBM       GOOGL       MSFT         IBM
# Date
# 2017-02-17  60.446514  136.764084  846.549988  64.620003  172.724670
# 2017-02-21  60.324905  136.453720  849.270020  64.489998  172.332703
# 2017-02-22  60.203300  137.127472  851.359985  64.360001  173.183563
# 2017-02-23  60.446514  137.505920  851.000000  64.620003  173.661575
# 2017-02-24  60.446514  137.278809  847.809998  64.620003  173.374756
#
# Attributes                   High                                Low  \
# Symbols          GOOGL       MSFT         IBM       GOOGL       MSFT
# Date
# 2017-02-17  846.549988  64.690002  173.585083  846.940002  64.300003
# 2017-02-21  849.270020  64.949997  172.839386  852.200012  64.449997
# 2017-02-22  851.359985  64.389999  173.365204  853.789978  64.050003
# 2017-02-23  851.000000  64.730003  174.474182  852.619995  64.190002
# 2017-02-24  847.809998  64.800003  173.508606  848.359985  64.139999
#
# Attributes                               Open                          \
# Symbols            IBM       GOOGL       MSFT         IBM       GOOGL
# Date
# 2017-02-17  172.084137  839.780029  64.470001  173.279160  841.309998
# 2017-02-21  171.242828  846.549988  64.610001  172.657745  847.989990
# 2017-02-22  172.170166  846.710022  64.330002  172.170166  848.000000
# 2017-02-23  172.963669  842.500000  64.419998  173.996170  851.080017
# 2017-02-24  171.978973  842.960022  64.529999  172.284897  847.650024
#
# Attributes      Volume
# Symbols           MSFT        IBM      GOOGL
# Date
# 2017-02-17  21248800.0  3715915.0  1461200.0
# 2017-02-21  20655900.0  4686394.0  1260300.0
# 2017-02-22  19292700.0  3159443.0  1224400.0
# 2017-02-23  20273100.0  2387495.0  1386700.0
# 2017-02-24  21796800.0  3451905.0  1346200.0

# %%
Base = stk_data.loc[:, ('Adj Close', 'MSFT')]
X1 = stk_data.loc[:, ('Adj Close', ('GOOGL', 'IBM'))]
X2 = ccy_data
X3 = idx_data

# %%
Base
# Out:
# Date
# 2017-02-17     60.446526
# 2017-02-21     60.324909
# 2017-02-22     60.203304
# 2017-02-23     60.446526
# 2017-02-24     60.446526
#                  ...
# 2022-02-10    302.380005
# 2022-02-11    295.040009
# 2022-02-14    295.000000
# 2022-02-15    300.470001
# 2022-02-16    299.500000
# Name: (Adj Close, MSFT), Length: 1259, dtype: float64

# %% [markdown]
# > ## z-norm x1 , x2 , x3

# %%
std = StandardScaler()

# %%
X1 = pd.DataFrame(std.fit_transform(X1.values), index = X1.index,columns=X1.columns)

# %%
X2[X2.columns] = std.fit_transform(X2)

# %%
X3[X3.columns] = std.fit_transform(X3)

# %% [markdown]
# > sum of base different

# %%
return_period = 3

# %%
Y = Base.shift(-return_period)
X4_3DT = Base.diff(3 *return_period).shift(-3 * return_period)
X4_6DT = Base.diff(6 *return_period).shift(-6 * return_period)
X4_12DT = Base.diff(12 *return_period).shift(-12 * return_period)

# %%
X4_3DT
# Out:
# Date
# 2017-02-17   -0.346111
# 2017-02-21   -0.205803
# 2017-02-22    0.037422
# 2017-02-23    0.346088
# 2017-02-24    0.102894
#                 ...
# 2022-02-10         NaN
# 2022-02-11         NaN
# 2022-02-14         NaN
# 2022-02-15         NaN
# 2022-02-16         NaN
# Name: (Adj Close, MSFT), Length: 1259, dtype: float64

# %%
X4 = pd.concat([X4_3DT,X4_6DT,X4_12DT] ,axis=1)

# %%
X4.columns = ['MSFT_3DT', 'MSFT_6DT', 'MSFT_12DT']

# %%
X4 = pd.DataFrame(std.fit_transform(X4.values), index = X4.index,columns=X4.columns)

# %%
X4
# Out:
#             MSFT_3DT  MSFT_6DT  MSFT_12DT
# Date
# 2017-02-17 -0.277713 -0.330138  -0.504419
# 2017-02-21 -0.259018 -0.298271  -0.513072
# 2017-02-22 -0.226609 -0.281453  -0.523886
# 2017-02-23 -0.185481 -0.368200  -0.504419
# 2017-02-24 -0.217885 -0.295617  -0.510909
# ...              ...       ...        ...
# 2022-02-10       NaN       NaN        NaN
# 2022-02-11       NaN       NaN        NaN
# 2022-02-14       NaN       NaN        NaN
# 2022-02-15       NaN       NaN        NaN
# 2022-02-16       NaN       NaN        NaN
#
# [1259 rows x 3 columns]

# %%
X4_null = X4[X4.isnull().any(axis=1)]
X4_null
# Out:
#             MSFT_3DT  MSFT_6DT  MSFT_12DT
# Date
# 2021-12-28 -3.826572 -4.578754        NaN
# 2021-12-29 -3.825238 -5.390653        NaN
# 2021-12-30 -3.036425 -4.363953        NaN
# 2021-12-31 -4.431510 -3.783891        NaN
# 2022-01-03 -3.502781 -2.838568        NaN
# 2022-01-04 -3.743960 -2.038027        NaN
# 2022-01-05 -1.970457 -1.052962        NaN
# 2022-01-06 -1.867855 -0.371652        NaN
# 2022-01-07 -2.631356 -1.542184        NaN
# 2022-01-10 -2.616697 -1.120147        NaN
# 2022-01-11 -3.761283 -1.659520        NaN
# 2022-01-12 -3.104377 -1.629239        NaN
# 2022-01-13 -0.892494  0.274650        NaN
# 2022-01-14 -0.490093 -1.071889        NaN
# 2022-01-18  0.878345 -1.052015        NaN
# 2022-01-19  0.491933 -1.120147        NaN
# 2022-01-20  1.348699 -0.438836        NaN
# 2022-01-21  0.463949 -0.003553        NaN
# 2022-01-24  1.043569       NaN        NaN
# 2022-01-25  1.428652       NaN        NaN
# 2022-01-26  0.814386       NaN        NaN
# 2022-01-27  1.283410       NaN        NaN
# 2022-01-28 -1.015082       NaN        NaN
# 2022-01-31 -2.355536       NaN        NaN
# 2022-02-01 -2.065061       NaN        NaN
# 2022-02-02 -1.962459       NaN        NaN
# 2022-02-03 -0.464776       NaN        NaN
# 2022-02-04       NaN       NaN        NaN
# 2022-02-07       NaN       NaN        NaN
# 2022-02-08       NaN       NaN        NaN
# 2022-02-09       NaN       NaN        NaN
# 2022-02-10       NaN       NaN        NaN
# 2022-02-11       NaN       NaN        NaN
# 2022-02-14       NaN       NaN        NaN
# 2022-02-15       NaN       NaN        NaN
# 2022-02-16       NaN       NaN        NaN

# %%
X4.describe()
# Out:
#            MSFT_3DT      MSFT_6DT     MSFT_12DT
# count  1.250000e+03  1.241000e+03  1.223000e+03
# mean  -2.291500e-17  1.230651e-16 -2.189581e-16
# std    1.000400e+00  1.000403e+00  1.000409e+00
# min   -4.431510e+00 -5.390653e+00 -3.877120e+00
# 25%   -3.492405e-01 -3.688053e-01 -4.577279e-01
# 50%   -1.983220e-03 -4.267481e-02 -9.484698e-02
# 75%    4.371854e-01  3.877326e-01  4.039771e-01
# max    3.483164e+00  3.746611e+00  4.189929e+00

# %% [markdown]
# > ## forming dataset

# %%
X = pd.concat([X1, X2, X3, X4], axis=1)

# %%
dataset = pd.concat([Y, X], axis=1)

# %%
dataset
# Out:
#             (Adj Close, MSFT)  (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS  \
# 2017-02-17          60.446526           -1.064010          2.019165       NaN
# 2017-02-20                NaN                 NaN               NaN       NaN
# 2017-02-21          60.446526           -1.059531          1.987920  1.372723
# 2017-02-22          60.081699           -1.056089          2.055745  1.365586
# 2017-02-23          59.847851           -1.056682          2.093853  1.087271
# ...                       ...                 ...               ...       ...
# 2022-02-10         300.470001            2.107294          1.692558  2.214805
# 2022-02-11         299.500000            1.964443          1.608996  2.239782
# 2022-02-14                NaN            2.005397          1.353274       NaN
# 2022-02-15                NaN            2.041048          1.332132       NaN
# 2022-02-16                NaN            2.078247          1.255616       NaN
#
#              DEXUSUK     SP500      DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  \
# 2017-02-17       NaN       NaN       NaN       NaN -0.277713 -0.330138
# 2017-02-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-02-21 -1.302417 -1.185361 -1.476403 -0.816162 -0.259018 -0.298271
# 2017-02-22 -1.319512 -1.189091 -1.468979 -0.796770 -0.226609 -0.281453
# 2017-02-23 -1.144764 -1.187649 -1.461073 -0.800192 -0.185481 -0.368200
# ...              ...       ...       ...       ...       ...       ...
# 2022-02-10  0.921825  1.930828  1.825349  0.591515       NaN       NaN
# 2022-02-11  0.855345  1.806338  1.710681  0.985071       NaN       NaN
# 2022-02-14       NaN  1.781612  1.671536  1.095724       NaN       NaN
# 2022-02-15       NaN  1.882731  1.767791  0.795708       NaN       NaN
# 2022-02-16       NaN  1.888472  1.755364       NaN       NaN       NaN
#
#             MSFT_12DT
# 2017-02-17  -0.504419
# 2017-02-20        NaN
# 2017-02-21  -0.513072
# 2017-02-22  -0.523886
# 2017-02-23  -0.504419
# ...               ...
# 2022-02-10        NaN
# 2022-02-11        NaN
# 2022-02-14        NaN
# 2022-02-15        NaN
# 2022-02-16        NaN
#
# [1304 rows x 11 columns]

# %%
dataset.head()
# Out:
#             (Adj Close, MSFT)  (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS  \
# 2017-02-17          60.446526           -1.064010          2.019165       NaN
# 2017-02-20                NaN                 NaN               NaN       NaN
# 2017-02-21          60.446526           -1.059531          1.987920  1.372723
# 2017-02-22          60.081699           -1.056089          2.055745  1.365586
# 2017-02-23          59.847851           -1.056682          2.093853  1.087271
#
#              DEXUSUK     SP500      DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  \
# 2017-02-17       NaN       NaN       NaN       NaN -0.277713 -0.330138
# 2017-02-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-02-21 -1.302417 -1.185361 -1.476403 -0.816162 -0.259018 -0.298271
# 2017-02-22 -1.319512 -1.189091 -1.468979 -0.796770 -0.226609 -0.281453
# 2017-02-23 -1.144764 -1.187649 -1.461073 -0.800192 -0.185481 -0.368200
#
#             MSFT_12DT
# 2017-02-17  -0.504419
# 2017-02-20        NaN
# 2017-02-21  -0.513072
# 2017-02-22  -0.523886
# 2017-02-23  -0.504419

# %% [markdown]
# # 5.1 (c) Data Preparation

# %%
null_data = dataset[dataset.isnull().any(axis=1)]
null_data
# Out:
#             (Adj Close, MSFT)  (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS  \
# 2017-02-17          60.446526           -1.064010          2.019165       NaN
# 2017-02-20                NaN                 NaN               NaN       NaN
# 2017-04-14                NaN                 NaN               NaN -0.357828
# 2017-05-29                NaN                 NaN               NaN       NaN
# 2017-07-04                NaN                 NaN               NaN       NaN
# ...                       ...                 ...               ...       ...
# 2022-02-10         300.470001            2.107294          1.692558  2.214805
# 2022-02-11         299.500000            1.964443          1.608996  2.239782
# 2022-02-14                NaN            2.005397          1.353274       NaN
# 2022-02-15                NaN            2.041048          1.332132       NaN
# 2022-02-16                NaN            2.078247          1.255616       NaN
#
#              DEXUSUK     SP500      DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  \
# 2017-02-17       NaN       NaN       NaN       NaN -0.277713 -0.330138
# 2017-02-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-04-14 -1.177054       NaN       NaN       NaN       NaN       NaN
# 2017-05-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-07-04       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-02-10  0.921825  1.930828  1.825349  0.591515       NaN       NaN
# 2022-02-11  0.855345  1.806338  1.710681  0.985071       NaN       NaN
# 2022-02-14       NaN  1.781612  1.671536  1.095724       NaN       NaN
# 2022-02-15       NaN  1.882731  1.767791  0.795708       NaN       NaN
# 2022-02-16       NaN  1.888472  1.755364       NaN       NaN       NaN
#
#             MSFT_12DT
# 2017-02-17  -0.504419
# 2017-02-20        NaN
# 2017-04-14        NaN
# 2017-05-29        NaN
# 2017-07-04        NaN
# ...               ...
# 2022-02-10        NaN
# 2022-02-11        NaN
# 2022-02-14        NaN
# 2022-02-15        NaN
# 2022-02-16        NaN
#
# [98 rows x 11 columns]

# %%
dataset.dropna(how="any",inplace=True)

# %%
dataset
# Out:
#             (Adj Close, MSFT)  (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS  \
# 2017-02-21          60.446526           -1.059531          1.987920  1.372723
# 2017-02-22          60.081699           -1.056089          2.055745  1.365586
# 2017-02-23          59.847851           -1.056682          2.093853  1.087271
# 2017-02-24          60.745850           -1.061935          2.070985  0.937409
# 2017-02-27          59.875912           -1.058872          1.922378  0.848205
# ...                       ...                 ...               ...       ...
# 2021-12-20         334.690002            2.205668          0.889926  1.362018
# 2021-12-21         342.450012            2.267107          1.079932  1.597516
# 2021-12-22         341.250000            2.364016          1.157525  1.636765
# 2021-12-23         341.950012            2.380532          1.245068  1.708128
# 2021-12-27         339.320007            2.413137          1.343552  1.861558
#
#              DEXUSUK     SP500      DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  \
# 2017-02-21 -1.302417 -1.185361 -1.476403 -0.816162 -0.259018 -0.298271
# 2017-02-22 -1.319512 -1.189091 -1.468979 -0.796770 -0.226609 -0.281453
# 2017-02-23 -1.144764 -1.187649 -1.461073 -0.800192 -0.185481 -0.368200
# 2017-02-24 -1.237837 -1.182505 -1.458467 -0.827570 -0.217885 -0.295617
# 2017-02-27 -1.287222 -1.178994 -1.454897 -0.756844 -0.144346 -0.275257
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-20  0.135458  2.023992  1.754883  0.472878  1.745774 -1.250732
# 2021-12-21  0.194340  2.142319  1.882534  0.260699 -0.002412 -2.663511
# 2021-12-22  0.369089  2.211281  1.942015 -0.010798 -2.472793 -3.158410
# 2021-12-23  0.492552  2.253870  1.986803 -0.087227 -3.004443 -3.463105
# 2021-12-27  0.545736  2.349161  2.066922 -0.119168 -4.017113 -4.724480
#
#             MSFT_12DT
# 2017-02-21  -0.513072
# 2017-02-22  -0.523886
# 2017-02-23  -0.504419
# 2017-02-24  -0.510909
# 2017-02-27  -0.508023
# ...               ...
# 2021-12-20  -1.917683
# 2021-12-21  -3.052337
# 2021-12-22  -3.510978
# 2021-12-23  -3.204189
# 2021-12-27  -3.877120
#
# [1206 rows x 11 columns]

# %%
null_data = dataset[dataset.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [(Adj Close, MSFT), (Adj Close, GOOGL), (Adj Close, IBM), DEXJPUS, DEXUSUK, SP500, DJIA, VIXCLS, MSFT_3DT, MSFT_6DT, MSFT_12DT]
# Index: []

# %% [markdown]
# > Assign X ,Y

# %%
dataset_nodate = dataset.reset_index(drop = "true")

# %%
Y = dataset_nodate.iloc[:,:1]
X = dataset_nodate.iloc[:,1:]

# %%
X.head()
# Out:
#    (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS   DEXUSUK     SP500  \
# 0           -1.059531          1.987920  1.372723 -1.302417 -1.185361
# 1           -1.056089          2.055745  1.365586 -1.319512 -1.189091
# 2           -1.056682          2.093853  1.087271 -1.144764 -1.187649
# 3           -1.061935          2.070985  0.937409 -1.237837 -1.182505
# 4           -1.058872          1.922378  0.848205 -1.287222 -1.178994
#
#        DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  MSFT_12DT
# 0 -1.476403 -0.816162 -0.259018 -0.298271  -0.513072
# 1 -1.468979 -0.796770 -0.226609 -0.281453  -0.523886
# 2 -1.461073 -0.800192 -0.185481 -0.368200  -0.504419
# 3 -1.458467 -0.827570 -0.217885 -0.295617  -0.510909
# 4 -1.454897 -0.756844 -0.144346 -0.275257  -0.508023

# %%
Y.head()
# Out:
#    (Adj Close, MSFT)
# 0          60.446526
# 1          60.081699
# 2          59.847851
# 3          60.745850
# 4          59.875912

# %% [markdown]
# > # Reduce Correlation Features

# %%
plt.figure(figsize=(10,8))
sns.heatmap(X.corr(),annot=True )
# Out:
# <AxesSubplot:>

# %%
#sns.pairplot(X, hue="SP500")

# %%
lower_cor = pd.DataFrame(np.tril(X.corr(), -1), columns = X.columns)
lower_cor
# Out:
#    (Adj Close, GOOGL)  (Adj Close, IBM)   DEXJPUS   DEXUSUK     SP500  \
# 0            0.000000          0.000000  0.000000  0.000000  0.000000
# 1            0.362814          0.000000  0.000000  0.000000  0.000000
# 2           -0.027775          0.260960  0.000000  0.000000  0.000000
# 3            0.515736          0.438206 -0.009325  0.000000  0.000000
# 4            0.981986          0.360138 -0.121192  0.520616  0.000000
# 5            0.944267          0.389558 -0.105738  0.556271  0.980717
# 6            0.151459         -0.510288 -0.450385 -0.208928  0.132127
# 7            0.097768         -0.020431 -0.000345  0.024714  0.090144
# 8            0.094787         -0.049627 -0.078127  0.047094  0.079738
# 9            0.124658         -0.019192 -0.217800  0.092792  0.099620
#
#        DJIA    VIXCLS  MSFT_3DT  MSFT_6DT  MSFT_12DT
# 0  0.000000  0.000000  0.000000  0.000000        0.0
# 1  0.000000  0.000000  0.000000  0.000000        0.0
# 2  0.000000  0.000000  0.000000  0.000000        0.0
# 3  0.000000  0.000000  0.000000  0.000000        0.0
# 4  0.000000  0.000000  0.000000  0.000000        0.0
# 5  0.000000  0.000000  0.000000  0.000000        0.0
# 6  0.053144  0.000000  0.000000  0.000000        0.0
# 7  0.080861  0.137663  0.000000  0.000000        0.0
# 8  0.069285  0.220740  0.682601  0.000000        0.0
# 9  0.086007  0.297431  0.363189  0.598706        0.0

# %% [markdown]
# > #### Drop features  correlation > |0.9|

# %%
to_drop = [column for column in lower_cor if any(lower_cor[column] > abs(0.9) )]
to_drop
# Out:
# [('Adj Close', 'GOOGL'), 'SP500']

# %%
X = X.drop(to_drop, axis=1)
X
# Out:
#       (Adj Close, IBM)   DEXJPUS   DEXUSUK      DJIA    VIXCLS  MSFT_3DT  \
# 0             1.987920  1.372723 -1.302417 -1.476403 -0.816162 -0.259018
# 1             2.055745  1.365586 -1.319512 -1.468979 -0.796770 -0.226609
# 2             2.093853  1.087271 -1.144764 -1.461073 -0.800192 -0.185481
# 3             2.070985  0.937409 -1.237837 -1.458467 -0.827570 -0.217885
# 4             1.922378  0.848205 -1.287222 -1.454897 -0.756844 -0.144346
# ...                ...       ...       ...       ...       ...       ...
# 1201          0.889926  1.362018  0.135458  1.754883  0.472878  1.745774
# 1202          1.079932  1.597516  0.194340  1.882534  0.260699 -0.002412
# 1203          1.157525  1.636765  0.369089  1.942015 -0.010798 -2.472793
# 1204          1.245068  1.708128  0.492552  1.986803 -0.087227 -3.004443
# 1205          1.343552  1.861558  0.545736  2.066922 -0.119168 -4.017113
#
#       MSFT_6DT  MSFT_12DT
# 0    -0.298271  -0.513072
# 1    -0.281453  -0.523886
# 2    -0.368200  -0.504419
# 3    -0.295617  -0.510909
# 4    -0.275257  -0.508023
# ...        ...        ...
# 1201 -1.250732  -1.917683
# 1202 -2.663511  -3.052337
# 1203 -3.158410  -3.510978
# 1204 -3.463105  -3.204189
# 1205 -4.724480  -3.877120
#
# [1206 rows x 8 columns]

# %% [markdown]
# # Train / Test Preparation

# %%
test_size = int(0.3 * len(X))
train_size = int(0.7 * len(X))
X_train, X_test = X[0:int(train_size)], X[int(train_size):len(X)]
Y_train, Y_test = Y[0:int(train_size)], Y[int(train_size):len(X)]

# %%
print("X_Train :",X_train.shape)
print("X_Test : ",X_test.shape)
print("Y_Train :",Y_train.shape)
print("Y_Test : ",Y_test.shape)
# Out:
# X_Train : (844, 8)
# X_Test :  (362, 8)
# Y_Train : (844, 1)
# Y_Test :  (362, 1)

# %% [markdown]
# # Model Training and Cross Validation

# %%
#Set number of fold / Seed value
Num_fold = 5
seed = 4

# %% [markdown]
# # Cross Validation Model
# > ## set k-fold crossvalidation with shuffle

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kfold = KFold(n_splits=Num_fold, shuffle = True, random_state=seed)

# %% [markdown]
# # Model selection

# %%
model_LM = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
c_val = 0.7

# %%
svr_lin = SVR(kernel='linear', C=c_val)
svr_rbf = SVR(kernel='rbf', C=c_val, gamma=0.01)
svr_poly = SVR(kernel='poly', C=c_val, degree=2)

# %% [markdown]
# # Calculate accuracy score for each model

# %%
score_LM = cross_val_score(model_LM, X_train, Y_train, cv=kfold)
score_LM
# Out:
# array([0.84060146, 0.84815228, 0.87210994, 0.88321237, 0.84524201])

# %%
score_lin = cross_val_score(svr_lin, X_train, Y_train, cv=kfold)
score_lin
# Out:
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# array([0.83372627, 0.76826022, 0.81825271, 0.82104197, 0.81361357])

# %%
score_rbf = cross_val_score(svr_rbf, X_train, Y_train, cv=kfold)
score_rbf
# Out:
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# array([0.26919014, 0.16385263, 0.257316  , 0.21637393, 0.21175651])

# %%
score_poly = cross_val_score(svr_poly, X_train, Y_train, cv=kfold)
score_poly
# Out:
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ACER-OAT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# array([0.59386827, 0.60422972, 0.59341326, 0.53488882, 0.50745094])

# %%
score = pd.DataFrame({'Linear Model':score_LM,'SVR_linear':score_lin, 'SVR_rbf': score_rbf, 'SVR_poly':score_poly})

# %%
score
# Out:
#    Linear Model  SVR_linear   SVR_rbf  SVR_poly
# 0      0.840601    0.833726  0.269190  0.593868
# 1      0.848152    0.768260  0.163853  0.604230
# 2      0.872110    0.818253  0.257316  0.593413
# 3      0.883212    0.821042  0.216374  0.534889
# 4      0.845242    0.813614  0.211757  0.507451

# %%
score_mean = pd.DataFrame({'AVG Linear Model':[score_LM.mean()],'AVG SVR_linear':[score_lin.mean()],
'AVG SVR_rbf': [score_rbf.mean()], 'AVG SVC_poly': [score_poly.mean()]})
score_mean
# Out:
#    AVG Linear Model  AVG SVR_linear  AVG SVR_rbf  AVG SVC_poly
# 0          0.857864        0.810979     0.223698       0.56677

# %%
ax = sns.barplot(data=score)

# %% [markdown]
# # 5.3 Prediction and Evaluation

# %%
LM_pred = model_LM.fit(X_train, Y_train).predict(X_test)
SVR_linear,

# %%
#plt.scatter(X_test.iloc[0:,2:3], LM_pred,c='r')

# %%
lw = 2

svrs = [svr_rbf, svr_lin, svr_poly]
kernel_label = ["RBF", "Linear", "Polynomial"]
model_color = ["m", "c", "g"]

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 10), sharey=True)
for ix, svr in enumerate(svrs):
    axes[ix].plot(
        X,
        svr.fit(X, y).predict(X),
        color=model_color[ix],
        lw=lw,
        label="{} model".format(kernel_label[ix]),
    )
    axes[ix].scatter(
        X[svr.support_],
        y[svr.support_],
        facecolor="none",
        edgecolor=model_color[ix],
        s=50,
        label="{} support vectors".format(kernel_label[ix]),
    )
    axes[ix].scatter(
        X[np.setdiff1d(np.arange(len(X)), svr.support_)],
        y[np.setdiff1d(np.arange(len(X)), svr.support_)],
        facecolor="none",
        edgecolor="k",
        s=50,
        label="other training data",
    )
    axes[ix].legend(
        loc="upper center",
        bbox_to_anchor=(0.5, 1.1),
        ncol=1,
        fancybox=True,
        shadow=True,
    )

fig.text(0.5, 0.04, "data", ha="center", va="center")
fig.text(0.06, 0.5, "target", ha="center", va="center", rotation="vertical")
fig.suptitle("Support Vector Regression", fontsize=14)
plt.show()
